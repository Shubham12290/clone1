# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham12290/clone1/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("nter"))
print(n)
# Out:
# nter5
# 5

# %%
p=int(input("enter"))
print(p)
# Out:
# enter45
# 45

# %%
p=int(input("w"))
p
# Out:
# w45
# 45

# %%
p=int(input("enter"))
p
# Out:
# enter48
# 48

# %%
r=int(input("enter"))
r
# Out:
# enter45
# 45

# %%
y=int(input("K"))
y
# Out:
# K45
# 45

# %%
u=int(input("e"))
u
# Out:
# e45
# 45

# %%
h=int(input("r"))
h
# Out:
# r45
# 45

# %%
n=int(input("enter"))
sum=0
n1=1
while(n1<=n):
  sum=sum+n1
  n1=n1+1

print(sum)
#User se number lo aur n se 1 tak reverse print karo
# Out:
# enter5
# 15

# %%
n=int(input("enter"))
n1=1
while(n1<=n):
   print(n)
   n=n-1

  #User se number lo aur batao usme kitne digits hain
# Out:
# enter5
# 5
# 4
# 3
# 2
# 1

# %%
n=int(input("enter"))
while(0<n):
  n1=n/10
print(n1)

# %%
n=45/10
n
# Out:
# 4.5

# %%
n=int(input("enter"))
n1=1
while(n1<=10):
  print(n1,"*",n,n1*n)
  n1=n1+1
# Out:
# enter5
# 1 * 5 5
# 2 * 5 10
# 3 * 5 15
# 4 * 5 20
# 5 * 5 25
# 6 * 5 30
# 7 * 5 35
# 8 * 5 40
# 9 * 5 45
# 10 * 5 50

# %%
n=(int(input("enter")))
count=0
while(0<n):
  n=n//10
  count=count+1
print(count)
# Out:
# enter456
