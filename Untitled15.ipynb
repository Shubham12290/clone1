# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham12290/clone1/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ppx=[1,2,3]
y=x
z=[1,2,3]
print(x is y)
print(z is not y)
# Out:
# True
# True

# %%
list=["shubham","raju"]
print  ("shubham" not in list)
# Out:
# False

# %%
year=int(input("enter the year"))
if(year%4==0 and year%100!=0) or (year%400==0):
  print("leap")
else:
  print("not")
# Out:
# enter the year1800
# not

# %%
pusername="s"
ppassword="1"
username=input("enter")
password=input("enter")
if pusername==username:
 if ppassword==password:
    print("k")
 else:
    print("l")
else:
  print("p")
# Out:
# enterhh5
# enter1'
# p

# %%
m=int(input("maths"))
p=int(input)

# %%
m=int(input("math"))
p=int(input("physic"))
c=int(input("chemistry"))
t=m+p+c
print(t)
tt=m+p
if(m>65 and p>55 and c>50) or(t>180 and tt>140):
  print("admission")
else:
  print("not")
# Out:
# math60
# physic60
# chemistry90
# 210
# not

# %%
def greting(a,b):
  return a+b
a=greting(2,5)
print(a)
# Out:
# 7

# %%
def add(a,b):
  return a+b
print(c)
c=add(1,2)
# Out:
# 3

# %%
def add(a,b):
  return a+b
print(add(1,2))
# Out:
# 3

# %%
def add(a,b):
  return a+b
c=add(4,5)
print(c)
